# %%
import os
import sys

# you can use the numpy library for random number generation: 
# http://docs.scipy.org/doc/numpy/reference/routines.random.html

import numpy as np

# %%
np.random.seed(seed=137164)

# %%
ReprRand=np.random.rand(2,100)

# %%
ReprRand.shape
# Out:
# (2, 100)

# %%
ReprRand
# Out:
# array([[ 0.67726484,  0.24992312,  0.68611514,  0.18409971,  0.74895543,
#          0.55361833,  0.32570361,  0.87355581,  0.56095899,  0.97535628,
#          0.91942069,  0.78464989,  0.02523615,  0.23528149,  0.34778384,
#          0.62463886,  0.41828883,  0.68760474,  0.07293484,  0.5378793 ,
#          0.09911172,  0.30954026,  0.20269734,  0.23984838,  0.78198134,
#          0.01313888,  0.81644928,  0.23055751,  0.48632888,  0.5226381 ,
#          0.25243011,  0.49910926,  0.82238491,  0.94474455,  0.17498737,
#          0.42791919,  0.18697309,  0.7229975 ,  0.68966503,  0.66691847,
#          0.48136029,  0.36251044,  0.38264246,  0.6254945 ,  0.82302716,
#          0.67600002,  0.36071857,  0.00945184,  0.94655425,  0.57430435,
#          0.04904849,  0.50810523,  0.04661679,  0.20404338,  0.30115724,
#          0.98405651,  0.93881187,  0.06640536,  0.6390003 ,  0.86123616,
#          0.02577069,  0.63932817,  0.40105799,  0.05978822,  0.906759  ,
#          0.98042204,  0.53847571,  0.18082209,  0.60271626,  0.79574744,
#          0.21904128,  0.11274475,  0.05502841,  0.97384767,  0.06378082,
#          0.45497031,  0.32183095,  0.37069615,  0.79014345,  0.63985439,
#          0.70728361,  0.99059695,  0.77086786,  0.49165161,  0.75910777,
#          0.94260444,  0.78945701,  0.29332688,  0.58404661,  0.02880228,
#          0.59317158,  0.86350477,  0.10476312,  0.16285646,  0.43602055,
#          0.74969383,  0.54579307,  0.26500029,  0.74965701,  0.01965423],
#        [ 0.47596059,  0.61053854,  0.20402379,  0.89027148,  0.40233759,
#          0.71158829,  0.81130364,  0.2137088 ,  0.5422256 ,  0.26488739,
#          0.91335554,  0.76157818,  0.3086875 ,  0.42222689,  0.66468096,
#          0.41385035,  0.56032629,  0.4863585 ,  0.26531084,  0.82784639,
#          0.76398649,  0.56944709,  0.51778335,  0.87243206,  0.30814393,
#          0.27557319,  0.75589854,  0.97424726,  0.09682717,  0.81009762,
#          0.68105964,  0.93036452,  0.93304262,  0.27010497,  0.62074415,
#          0.00407773,  0.67543449,  0.85043754,  0.45201748,  0.84729105,
#          0.00610142,  0.89745785,  0.74153868,  0.93378427,  0.61011328,
#          0.37552456,  0.19680558,  0.93739458,  0.0819788 ,  0.7089514 ,
#          0.76001295,  0.90401997,  0.19778652,  0.74652623,  0.36741967,
#          0.07481594,  0.55483588,  0.37138126,  0.27948347,  0.09699033,
#          0.38848726,  0.51831001,  0.9364722 ,  0.04183904,  0.3698409 ,
#          0.57906262,  0.95444652,  0.64182421,  0.90896528,  0.57813066,
#          0.51456556,  0.5550008 ,  0.40602041,  0.51816636,  0.34609299,
#          0.63451796,  0.57102398,  0.37322424,  0.48891764,  0.9124195 ,
#          0.59401614,  0.0853063 ,  0.17171487,  0.97927253,  0.24955188,
#          0.33634753,  0.30551643,  0.56778421,  0.93097779,  0.46340456,
#          0.66781158,  0.18738735,  0.04312757,  0.3882844 ,  0.42798164,
#          0.899199  ,  0.71585202,  0.16118564,  0.1806375 ,  0.91737132]])

# %%
ReprRandAll = np.zeros((50, 2, 100))
for i in range(50):
    ReprRandAll [i]=i*np.random.randn(2,100)+i

# %%
ReprRandAll.shape
# Out:
# (50, 2, 100)

# %%
import pylab as pl
# %pylab inline

for i in range(50):
    pl.plot(ReprRandAll[i], 'r--')
    
plt.xlabel('Points')
plt.ylabel('Values')
plt.title('Plot of random distributions')
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib
